# %%
import pandas as pd
import numpy as np
import seaborn as sns

#Load the data
df = pd.read_csv('/Users/corneliastackhouse/Documents/Greenbootcamps/Project_Data_Professions_career_shift/data/salaries.csv')


#View the data
df.head()
# Out:
#    work_year experience_level employment_type       job_title  salary  \
# 0       2025               SE              FT         Manager  115000
# 1       2025               SE              FT         Manager   85000
# 2       2025               SE              FT      Consultant  171800
# 3       2025               SE              FT      Consultant   96600
# 4       2025               MI              FT  Data Scientist  145000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             USD         115000                 US             0
# 1             USD          85000                 US             0
# 2             USD         171800                 US             0
# 3             USD          96600                 US             0
# 4             USD         145000                 US             0
#
#   company_location company_size
# 0               US            M
# 1               US            M
# 2               US            M
# ...

# %%
df.describe()
# Out:
#           work_year        salary  salary_in_usd  remote_ratio
# count  73306.000000  7.330600e+04   73306.000000  73306.000000
# mean    2023.833711  1.625969e+05  157987.709151     21.560991
# std        0.480106  1.929621e+05   72504.604716     41.008080
# min     2020.000000  1.400000e+04   15000.000000      0.000000
# 25%     2024.000000  1.068400e+05  106800.000000      0.000000
# 50%     2024.000000  1.480000e+05  147500.000000      0.000000
# 75%     2024.000000  2.000000e+05  199700.000000      0.000000
# max     2025.000000  3.040000e+07  800000.000000    100.000000

# %%
european_countries = [
    'AL', 'AD', 'AM', 'AT', 'AZ', 'BY', 'BE', 'BA', 'BG', 'CH', 'CY', 'CZ', 'DE', 'DK',
    'EE', 'ES', 'FI', 'FR', 'GE', 'GR', 'GB', 'HR', 'HU', 'IE', 'IS', 'IT', 'KZ', 'LI', 'LT',
    'LU', 'LV', 'MC', 'MD', 'ME', 'MK', 'MT', 'NL', 'NO', 'PL', 'PT', 'RO', 'RS', 'RU',
    'SE', 'SI', 'SK', 'SM', 'TR', 'UA', 'UK', 'VA'
]

# %%
european_countries = [ 'AL', 'AD', 'AM', 'AT', 'AZ', 'BY', 'BE', 'BA', 'BG', 'CH', 'CY', 'CZ', 'DE', 'DK',
    'EE', 'ES', 'FI', 'FR', 'GE', 'GR', 'GB', 'HR', 'HU', 'IE', 'IS', 'IT', 'KZ', 'LI', 'LT',
    'LU', 'LV', 'MC', 'MD', 'ME', 'MK', 'MT', 'NL', 'NO', 'PL', 'PT', 'RO', 'RS', 'RU',
    'SE', 'SI', 'SK', 'SM', 'TR', 'UA', 'UK', 'VA' ]  # List of European country codes as shown above
europe_df = df[df['company_location'].isin(european_countries)]
print(europe_df)
# Out:
#        work_year experience_level employment_type                  job_title  \
# 66          2025               SE              FT                   Engineer
# 67          2025               SE              FT                   Engineer
# 146         2025               EN              FT               Data Analyst
# 147         2025               EN              FT               Data Analyst
# 166         2025               EN              FT             Data Scientist
# ...          ...              ...             ...                        ...
# 73282       2020               SE              FT             Data Scientist
# 73283       2020               MI              FT             Data Scientist
# 73290       2021               MI              FT              Data Engineer
# 73295       2020               SE              FT  Machine Learning Engineer
# 73299       2021               MI              FT              Data Engineer
#
# ...

# %%
europe_df.to_csv('european_jobs.csv', index=False)

# %%
df = pd.read_csv('/Users/corneliastackhouse/Documents/Greenbootcamps/Project_Data_Professions_career_shift/data/european_jobs.csv')

# %%
df.describe()
# Out:
#          work_year        salary  salary_in_usd  remote_ratio
# count  1574.000000  1.574000e+03    1574.000000   1574.000000
# mean   2023.534943  1.043944e+05   78540.034943     26.556544
# std       0.920066  3.967020e+05   51205.080649     41.887571
# min    2020.000000  1.400000e+04   15129.000000      0.000000
# 25%    2023.000000  4.200000e+04   45555.000000      0.000000
# 50%    2024.000000  6.000000e+04   64781.000000      0.000000
# 75%    2024.000000  9.360000e+04   94444.000000     50.000000
# max    2025.000000  1.100000e+07  465972.000000    100.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming you have a DataFrame named 'data'
sns.set(style="whitegrid")

# Create the boxplot
plt.figure(figsize=(8, 6))
sns.boxplot(x=df['remote_ratio'], color="skyblue")
plt.title("Boxplot of Remote Ratios", fontsize=16)
plt.xlabel("Remote Ratio", fontsize=12)
plt.show()
